# %% [markdown]
# Assigment 9 - AI for Autonomous Vehicles
# Detect rear of cars
# TBD

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-161-ge54e758 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 40.0/166.8 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Train**

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data bdd100k.yaml --weights best_001.pt --name AI4AV_results --cache --project '../drive/MyDrive/bdd100k' --name 'backup_final'
# Out:
# train: weights=best_001.pt, cfg=, data=bdd100k.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../drive/MyDrive/bdd100k, name=backup_final, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-161-ge54e758 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# **Val**

# %%
# !python val.py --weights best_001.pt --data bdd100k.yaml --img 640 --iou 0.65 --half --task val
# Out:
# val: data=/content/yolov5/data/bdd100k.yaml, weights=['best_001.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-161-ge54e758 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning '/content/drive/MyDrive/bdd100k/val_all/labels.cache' images and labels... 10000 found, 0 missing, 378 empty, 0 corrupt: 100% 10000/10000 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 313/313 [01:19<00:00,  3.93it/s]
#                  all      10000      84346      0.599      0.375        0.4      0.257
#                  car      10000      79630      0.705      0.554      0.601      0.352
# ...

# %% [markdown]
# **Test**

# %%
# !python detect.py --classes 3 --weights best_001.pt --data data/bdd100k.yaml --img 640 --conf 0.25 --source ../drive/MyDrive/bdd100k/test/images
# Out:
# detect: weights=['best.pt'], source=../drive/MyDrive/bdd100k/test/images, data=data/bdd100k.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=[3], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-146-gb804b36 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1881 /content/drive/MyDrive/bdd100k/test/images/cabc9045-581f64de.jpg: 384x640 Done. (0.010s)
# image 2/1881 /content/drive/MyDrive/bdd100k/test/images/cac07407-fe32e494.jpg: 384x640 Done. (0.008s)
# image 3/1881 /content/drive/MyDrive/bdd100k/test/images/cad17389-cb0208f5.jpg: 384x640 Done. (0.007s)
# ...

# %%
# !python detect.py --classes 3 --weights best_001.pt --data data/bdd100k.yaml --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['best_001.pt'], source=data/images, data=data/bdd100k.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[3], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-161-ge54e758 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/5 /content/yolov5/data/images/bus.jpg: 640x480 Done. (0.015s)
# image 2/5 /content/yolov5/data/images/test1.jpg: 384x640 Done. (0.016s)
# image 3/5 /content/yolov5/data/images/test2.jpg: 384x640 Done. (0.012s)
# image 4/5 /content/yolov5/data/images/test3.jpg: 384x640 Done. (0.012s)
# image 5/5 /content/yolov5/data/images/zidane.jpg: 384x640 Done. (0.012s)
# ...
